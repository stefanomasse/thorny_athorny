# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from functions_for_parameter_sweeps import *

# %%
diff_bt_aa = prepare_plotting_2parameters('aa','tb')
diff_tb_bt = prepare_plotting_2parameters('bt','tb')
diff_tb_ba = prepare_plotting_2parameters('ba','tb')
diff_ta_ba = prepare_plotting_2parameters('ba','ta')
diff_ab_ba = prepare_plotting_2parameters('ba','ab')
diff_tb_ab = prepare_plotting_2parameters('ab','tb')
diff_ta_ab = prepare_plotting_2parameters('ab','ta')
diff_aa_ab = prepare_plotting_2parameters('ab','aa')
diff_aa_ba = prepare_plotting_2parameters('ba','aa')
diff_ta_tb = prepare_plotting_2parameters('tb','ta')
diff_aa_bt = prepare_plotting_2parameters('bt','aa')
diff_ta_bt = prepare_plotting_2parameters('bt','ta')
diff_ba_bt = prepare_plotting_2parameters('ba','bt')
diff_ab_bt = prepare_plotting_2parameters('bt','ab')

diff_ta_at = prepare_plotting_2parameters('ta','at')
diff_aa_ta = prepare_plotting_2parameters('aa','ta')
diff_aa_at = prepare_plotting_2parameters('aa','at')
diff_tt_at = prepare_plotting_2parameters('tt','at')
diff_aa_tt = prepare_plotting_2parameters('aa','tt')
diff_ta_tt = prepare_plotting_2parameters('ta','tt')

# %%
the_fontsize=32
numberfont=32
plt.rc('font', size=the_fontsize)

fig = plt.figure(figsize=(18,22.125),constrained_layout=True)
fig.text(-0.05, 0.395, r'Connectivity [%]', rotation=90,fontsize=the_fontsize)
fig.text(0.43, 1.02, r'Connectivity [%]', rotation=0,fontsize=the_fontsize)

ax8=plt.subplot(5,4,1)
plt.imshow(diff_aa_bt.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax8.set_facecolor('lightgray')
plt.ylabel(r'A$\rightarrow$A')
ax8.set_yticks([2,6,10,14,18])
plt.xlabel(r'T$\rightarrow$B',labelpad=15,fontsize=the_fontsize)
ax8.xaxis.set_ticks_position('top')
ax8.xaxis.set_label_position('top')
ax8.set_xticks([12,16,20,24,28])
ax8.set_xticklabels(["12", "", "20", "", "28"])
ax8.set_yticks([2,6,10,14,18])
ax8.set_yticklabels(["2", "", "10", "", "18"])
ax8.tick_params(axis='both', which='major', length=6, width=2)
ax8.text(0.95, 0.05, '1', transform=ax8.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax7=plt.subplot(5,4,2)
plt.imshow(diff_aa_ba.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax7.set_facecolor('lightgray')
plt.xlabel(r'A$\rightarrow$B',labelpad=15)
ax7.xaxis.set_ticks_position('top')
ax7.xaxis.set_label_position('top')
ax7.set_xticks([12,16,20,24,28])
ax7.set_xticklabels(["12", "", "20", "", "28"])
ax7.set_yticks([])
ax7.tick_params(axis='both', which='major', length=6, width=2)
ax7.tick_params(axis='y', which='both', length=0)
ax7.text(0.95, 0.05, '2', transform=ax7.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax5=plt.subplot(5,4,3)
plt.imshow(diff_bt_aa,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax5.set_facecolor('lightgray')
plt.xlabel(r'B$\rightarrow$T',labelpad=15)
ax5.xaxis.set_ticks_position('top')
ax5.xaxis.set_label_position('top')
ax5.set_xticks([12,16,20,24,28])
ax5.set_xticklabels(["12", "", "20", "", "28"])
ax5.set_yticks([])
ax5.tick_params(axis='both', which='major', length=6, width=2)
ax5.tick_params(axis='y', which='both', length=0)
ax5.text(0.95, 0.05, '3', transform=ax5.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax6=plt.subplot(5,4,4)
plt.imshow(diff_aa_ab.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax6.set_facecolor('lightgray')
ax6.set_yticks([])
plt.xlabel(r'B$\rightarrow$A',labelpad=15)
ax6.xaxis.set_ticks_position('top')
ax6.xaxis.set_label_position('top')
ax6.set_xticks([12,16,20,24,28])
ax6.set_xticklabels(["12", "", "20", "", "28"])
ax6.tick_params(axis='both', which='major', length=6, width=2)
ax6.tick_params(axis='y', which='both', length=0)
ax6.text(0.95, 0.05, '4', transform=ax6.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax4=plt.subplot(5,4,5)
plt.imshow(diff_ta_bt.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax4.set_facecolor('lightgray')
plt.ylabel(r'A$\rightarrow$T')
ax4.set_xticks([])
ax4.set_yticks([2,6,10,14,18])
ax4.set_yticklabels(["2", "", "10", "", "18"])
ax4.tick_params(axis='both', which='major', length=6, width=2)
ax4.tick_params(axis='x', which='both', length=0)
ax4.text(0.95, 0.05, '5', transform=ax4.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax3=plt.subplot(5,4,6)
plt.imshow(diff_ta_ba.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax3.set_facecolor('lightgray')
ax3.set_xticks([])
ax3.set_yticks([])
ax3.tick_params(axis='both', which='both', length=0)
ax3.text(0.95, 0.05, '6', transform=ax3.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax1=plt.subplot(5,4,7)
plt.imshow(diff_ta_tb.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax1.set_facecolor('lightgray')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.tick_params(axis='both', which='both', length=0)
ax1.text(0.95, 0.05, '7', transform=ax1.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax2=plt.subplot(5,4,8)
plt.imshow(diff_ta_ab.T,vmin=-100,vmax=100,extent=[10,30,0,20],origin='lower',cmap='seismic')
plt.plot(20, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax2.set_facecolor('lightgray')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.tick_params(axis='both', which='both', length=0)
ax2.text(0.95, 0.05, '8', transform=ax2.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax16=plt.subplot(5,4,9)
plt.imshow(diff_ab_bt.T,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax16.set_facecolor('lightgray')
plt.ylabel(r'B$\rightarrow$A')
ax16.set_yticks([12,16,20,24,28])
ax16.set_yticklabels(["12", "", "20", "", "28"])
ax16.set_xticks([])
ax16.tick_params(axis='both', which='major', length=6, width=2)
ax16.tick_params(axis='x', which='both', length=0)
ax16.text(0.95, 0.05, '9', transform=ax16.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax15=plt.subplot(5,4,10)
plt.imshow(diff_ab_ba.T,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax15.set_facecolor('lightgray')
ax15.set_xticks([])
ax15.set_yticks([])
ax15.tick_params(axis='both', which='both', length=0)
ax15.text(0.95, 0.05, '10', transform=ax15.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax10=plt.subplot(5,4,11)
plt.imshow(diff_tb_ab,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax10.set_facecolor('lightgray')
ax10.set_xticks([])
ax10.set_yticks([])
ax10.tick_params(axis='both', which='both', length=0)
ax10.text(0.95, 0.05, '11', transform=ax10.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax12=plt.subplot(5,4,13)
plt.imshow(diff_tb_bt.T,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax12.set_facecolor('lightgray')
plt.ylabel(r'B$\rightarrow$T')
ax12.set_yticks([12,16,20,24,28])
ax12.set_yticklabels(["12", "", "20", "", "28"])
ax12.set_xticks([])
ax12.tick_params(axis='both', which='major', length=6, width=2)
ax12.tick_params(axis='x', which='both', length=0)
ax12.text(0.95, 0.05, '12', transform=ax12.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax11=plt.subplot(5,4,14)
plt.imshow(diff_tb_ba.T,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax11.set_facecolor('lightgray')
ax11.set_xticks([])
ax11.set_yticks([])
ax11.tick_params(axis='both', which='both', length=0)
ax11.text(0.95, 0.05, '13', transform=ax11.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax17=plt.subplot(5,4,17)
plt.imshow(diff_ba_bt,vmin=-100,vmax=100,extent=[10,30,10,30],origin='lower',cmap='seismic')
plt.plot(20, 20, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax17.set_facecolor('lightgray')
ax17.set_yticks([12,16,20,24,28])
ax17.set_yticklabels(["12", "", "20", "", "28"])
ax17.set_xticks([])
plt.ylabel(r'A$\rightarrow$B')
ax17.tick_params(axis='both', which='major', length=6, width=2)
ax17.tick_params(axis='x', which='both', length=0)
ax17.text(0.95, 0.05, '14', transform=ax17.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))
plt.show()

# %%
plt.rc('font', size=32)
fig=plt.figure(figsize=(13.78,15.2),constrained_layout=True)
fig.text(-0.05, 0.4, r'Connectivity [%]', rotation=90,fontsize=the_fontsize)
fig.text(0.415, 1.033, r'Connectivity [%]', rotation=0,fontsize=the_fontsize)

ax1=plt.subplot(3,3,1)
plt.imshow(diff_aa_tt,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(8,15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax1.set_facecolor('lightgray')
ax1.set_xticks([2,6,10,14,18])
ax1.set_xticklabels(["2", "", "10", "", "18"])
ax1.set_yticks([2,6,10,14,18])
ax1.set_yticklabels(["2", "", "10", "", "18"])
ax1.xaxis.set_ticks_position('top')
ax1.xaxis.set_label_position('top')
plt.xlabel(r'T$\rightarrow$T',labelpad=15)
plt.ylabel(r'A$\rightarrow$A')
ax1.tick_params(axis='both', which='major', length=6, width=2)
ax1.text(0.95, 0.05, '1', transform=ax1.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax2=plt.subplot(3,3,2)
plt.imshow(diff_aa_at,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(11,15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax2.set_facecolor('lightgray')
ax2.set_xticks([2,6,10,14,18])
ax2.set_xticklabels(["2", "", "10", "", "18"])
ax2.set_yticks([])
ax2.xaxis.set_ticks_position('top')
ax2.xaxis.set_label_position('top')
plt.xlabel(r'T$\rightarrow$A',labelpad=15)
ax2.tick_params(axis='both', which='major', length=6, width=2)
ax2.tick_params(axis='y', which='both', length=0)
ax2.text(0.95, 0.05, '2', transform=ax2.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax3=plt.subplot(3,3,3)
plt.imshow(diff_aa_ta,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(4,15, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax3.set_facecolor('lightgray')
ax3.set_xticks([2,6,10,14,18])
ax3.set_xticklabels(["2", "", "10", "", "18"])
ax3.set_yticks([])
ax3.xaxis.set_ticks_position('top')
ax3.xaxis.set_label_position('top')
plt.xlabel(r'A$\rightarrow$T',labelpad=15)
ax3.tick_params(axis='both', which='major', length=6, width=2)
ax3.tick_params(axis='y', which='both', length=0)
ax3.text(0.95, 0.05, '3', transform=ax3.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax4=plt.subplot(3,3,4)
plt.imshow(diff_ta_tt,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(8, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax4.set_facecolor('lightgray')
ax4.set_xticks([])
plt.ylabel(r'A$\rightarrow$T')
ax4.set_yticks([2,6,10,14,18])
ax4.set_yticklabels(["2", "", "10", "", "18"])
ax4.tick_params(axis='both', which='major', length=6, width=2)
ax4.tick_params(axis='x', which='both', length=0)
ax4.text(0.95, 0.05, '4', transform=ax4.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax5=plt.subplot(3,3,5)
plt.imshow(diff_ta_at,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(11, 4, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax5.set_facecolor('lightgray')
ax5.set_xticks([])
ax5.set_yticks([])
ax5.tick_params(axis='both', which='both', length=0)
ax5.text(0.95, 0.05, '5', transform=ax5.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

ax6=plt.subplot(3,3,7)
plt.imshow(diff_tt_at.T,vmin=-100,vmax=100,extent=[0,20,0,20],origin='lower',cmap='seismic')
plt.plot(8, 11, 'o', color='white', markersize=10, markeredgecolor='black', markeredgewidth=2)
ax6.set_facecolor('lightgray')
plt.ylabel(r'T$\rightarrow$A')
ax6.set_yticks([2,6,10,14,18])
ax6.set_yticklabels(["2", "", "10", "", "18"])
ax6.set_xticks([])
ax6.tick_params(axis='both', which='major', length=6, width=2)
ax6.tick_params(axis='x', which='both', length=0)
ax6.text(0.95, 0.05, '6', transform=ax6.transAxes,
        fontsize=numberfont, verticalalignment='bottom', horizontalalignment='right',
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8))

cbar = plt.colorbar(location='bottom', pad=0.05,shrink=1)
cbar.set_label(r'A$-$T Delay [ms]',labelpad=10)
cbar.set_ticks([-80,-40,0,40,80])
cbar.set_ticklabels(["-80", "", "0", "", "80"])

plt.show()
