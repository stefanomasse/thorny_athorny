# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from functions_for_parameter_sweeps import *

# %%
xaxis_plot=np.arange(0,20.5,0.5)

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('aa')

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 15, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 18.5, 100+contour_start_a1[37], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 5, -100+contour_end_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=10, ymax=18.5,color='gray')
ax1.vlines(x=100, ymin=5, ymax=10,color='gray')
ax1.hlines(y=15, xmin=-150, xmax=contour_start_a1[30], color='k', linestyle='--')
ax1.hlines(y=15, xmin=contour_end_t[30], xmax=150, color='k', linestyle='--')

custom_text = r"A$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=45, xmax=95,color='k')
ax2.vlines(x=95, ymin=45, ymax=60,color='k')
ax2.text(5, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(20, 42, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-100,100])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2) 
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[37,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[37,:],'magenta')
ax3.hlines(y=43, xmin=65, xmax=115,color='k')
ax3.vlines(x=115, ymin=43, ymax=58,color='k')
ax3.text(25, 55, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(45, 40, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-75,125])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')

plt.tight_layout()
plt.show()

# %%
# We care about the second peak only for the a-to-t connectivity, as such peaks are far less
# prominent for different values of the other connectivities
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('ta', plot_second_peak=True)

# %%
xaxis_plot = np.arange(0, 20.5, 0.5)
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)

fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals12, interpolation='nearest', cmap=cmap12, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a2, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
#ax1.scatter(0,5.4,color='white',marker='o',s=100,zorder=5)
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 4, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 1.5, 100+contour_start_a1[3], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 15, -100+contour_end_a1[30], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=100, ymin=10, ymax=15,color='gray')
ax1.vlines(x=-100, ymin=1.5, ymax=10,color='gray')
ax1.hlines(y=4, xmin=-150, xmax=contour_start_a1[8], color='k', linestyle='--')
ax1.hlines(y=4, xmin=contour_end_t[8], xmax=150, color='k', linestyle='--')
custom_text = r"A$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[3,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[3,:],'magenta')
ax2.hlines(y=43, xmin=-5, xmax=45,color='k')
ax2.vlines(x=45, ymin=43, ymax=58,color='k')
ax2.text(-45, 55.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-20, 41, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-50,150])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[30,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[30,:],'magenta')
ax3.hlines(y=45, xmin=40, xmax=90,color='k')
ax3.vlines(x=90, ymin=45, ymax=60,color='k')
ax3.text(0, 57.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(20, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('at')

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = plt.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = plt.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
plt.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
plt.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
plt.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
plt.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
plt.ylim([0,20])
plt.xlim([-150,150])
plt.xticks([-100,-50,0,50,100])
plt.yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 11, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 1, 100+contour_start_a1[2], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(-100, 18, 100+contour_start_a1[36], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=11, xmin=-150, xmax=contour_start_a1[22], color='k', linestyle='--')
ax1.hlines(y=11, xmin=contour_end_t[22], xmax=150, color='k', linestyle='--')
custom_text = r"T$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[2,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[2,:],'magenta')
ax2.hlines(y=45, xmin=-55, xmax=-5,color='k')
ax2.vlines(x=-5, ymin=45, ymax=60,color='k')
ax2.text(-95, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-70, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-100,100])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[36,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[36,:],'magenta')
ax3.hlines(y=45, xmin=45, xmax=95,color='k')
ax3.vlines(x=95, ymin=45, ymax=60,color='k')
ax3.text(5, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(25, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('tt')

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 8, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 5, 100+contour_start_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=8, xmin=-150, xmax=contour_start_a1[16], color='k', linestyle='--')
ax1.hlines(y=8, xmin=contour_end_t[16], xmax=150, color='k', linestyle='--')
#ax1.hlines(y=11, xmin=-100, xmax=contour_start_a1[22], color='gray', linestyle='-')
ax1.arrow(-100, 11, 100+contour_start_a1[22], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=11, ymax=20, color='gray', linestyle='-')
custom_text = r"T$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=65, xmax=115,color='k')
ax2.vlines(x=115, ymin=45, ymax=60,color='k')
ax2.text(20, 57, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(40, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-75,125])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[22,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[22,:],'magenta')
ax3.hlines(y=50, xmin=-80, xmax=-30,color='k')
ax3.vlines(x=-30, ymin=50, ymax=65,color='k')
ax3.text(-120, 62.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(-95, 48, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-125,75])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')

plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('aa', plastic_ee=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
#ax1.scatter(0,13.65,color='white',marker='o',s=100,zorder=5)
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 15, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 18, 100+contour_start_a1[36], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 5, -100+contour_end_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=10, ymax=18,color='gray')
ax1.vlines(x=100, ymin=5, ymax=10,color='gray')
ax1.hlines(y=15, xmin=-150, xmax=contour_start_a1[30], color='k', linestyle='--')
ax1.hlines(y=15, xmin=contour_end_t[30], xmax=150, color='k', linestyle='--')

custom_text = r"A$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=45, xmax=95,color='k')
ax2.vlines(x=95, ymin=45, ymax=60,color='k')
ax2.text(5, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(20, 42, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-100,100])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[36,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[36,:],'magenta')
ax3.hlines(y=63, xmin=65, xmax=115,color='k')
ax3.vlines(x=115, ymin=63, ymax=83,color='k')
ax3.text(25, 80, '20 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(45, 60, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-75,125])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')

plt.tight_layout()
plt.show()

# %%
# We care about the second peak only for the a-to-t connectivity, as such peaks are far less
# prominent for different values of the other connectivities
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('ta', plastic_ee=True, plot_second_peak=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)

fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals12, interpolation='nearest', cmap=cmap12, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a2, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
#ax1.scatter(0,5.4,color='white',marker='o',s=100,zorder=5)
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 4, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 1.5, 100+contour_start_a1[3], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 15, -100+contour_end_a1[30], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=100, ymin=10, ymax=15,color='gray')
ax1.vlines(x=-100, ymin=1.5, ymax=10,color='gray')
ax1.hlines(y=4, xmin=-150, xmax=contour_start_a1[8], color='k', linestyle='--')
ax1.hlines(y=4, xmin=contour_end_t[8], xmax=150, color='k', linestyle='--')
custom_text = r"A$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[3,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[3,:],'magenta')
ax2.hlines(y=43, xmin=-5, xmax=45,color='k')
ax2.vlines(x=45, ymin=43, ymax=58,color='k')
ax2.text(-45, 55.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-20, 41, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-50,150])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[30,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[30,:],'magenta')
ax3.hlines(y=45, xmin=40, xmax=90,color='k')
ax3.vlines(x=90, ymin=45, ymax=60,color='k')
ax3.text(0, 57.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(20, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('at', plastic_ee=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = plt.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = plt.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
plt.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
plt.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
plt.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
plt.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
plt.ylim([0,20])
plt.xlim([-150,150])
plt.xticks([-100,-50,0,50,100])
plt.yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 11, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 1, 100+contour_start_a1[2], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(-100, 15, 100+contour_start_a1[30], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=11, xmin=-150, xmax=contour_start_a1[22], color='k', linestyle='--')
ax1.hlines(y=11, xmin=contour_end_t[22], xmax=150, color='k', linestyle='--')
custom_text = r"T$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[2,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[2,:],'magenta')
ax2.hlines(y=45, xmin=-55, xmax=-5,color='k')
ax2.vlines(x=-5, ymin=45, ymax=60,color='k')
ax2.text(-95, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-70, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-100,100])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[30,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[30,:],'magenta')
ax3.hlines(y=45, xmin=45, xmax=95,color='k')
ax3.vlines(x=95, ymin=45, ymax=60,color='k')
ax3.text(5, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(25, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('tt', plastic_ee=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 8, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 5, 100+contour_start_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=8, xmin=-150, xmax=contour_start_a1[16], color='k', linestyle='--')
ax1.hlines(y=8, xmin=contour_end_t[16], xmax=150, color='k', linestyle='--')
#ax1.hlines(y=11, xmin=-100, xmax=contour_start_a1[22], color='gray', linestyle='-')
ax1.arrow(-100, 11, 100+contour_start_a1[22], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=11, ymax=20, color='gray', linestyle='-')
custom_text = r"T$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=65, xmax=115,color='k')
ax2.vlines(x=115, ymin=45, ymax=60,color='k')
ax2.text(20, 57, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(40, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-75,125])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[22,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[22,:],'magenta')
ax3.hlines(y=50, xmin=-80, xmax=-30,color='k')
ax3.vlines(x=-30, ymin=50, ymax=65,color='k')
ax3.text(-120, 62.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(-95, 48, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-125,75])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')


plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('aa', plot_frac=0.45, heterogenous=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
#ax1.scatter(0,13.65,color='white',marker='o',s=100,zorder=5)
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 15, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 16.5, 100+contour_start_a1[33], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 7.5,-100+contour_end_t[15], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=10, ymax=16.5,color='gray')
ax1.vlines(x=100, ymin=7, ymax=10,color='gray')
ax1.hlines(y=15, xmin=-150, xmax=contour_start_a1[30], color='k', linestyle='--')
ax1.hlines(y=15, xmin=contour_end_t[30], xmax=150, color='k', linestyle='--')

custom_text = r"A$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[15,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[15,:],'magenta')
ax2.hlines(y=45, xmin=70, xmax=120,color='k')
ax2.vlines(x=120, ymin=45, ymax=60,color='k')
ax2.text(30, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(45, 42, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-75,125])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[33,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[33,:],'magenta')
ax3.hlines(y=43, xmin=65, xmax=115,color='k')
ax3.vlines(x=115, ymin=43, ymax=58,color='k')
ax3.text(25, 55, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(45, 40, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-75,125])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')

plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('ta', plot_frac=0.45, heterogenous=True, plot_second_peak=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)

fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals12, interpolation='nearest', cmap=cmap12, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a2, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a2, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
#ax1.scatter(0,5.4,color='white',marker='o',s=100,zorder=5)
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'A$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 4, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 2, 100+contour_start_a1[4], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(100, 10, -100+0, 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=100, ymin=10, ymax=10,color='gray')
ax1.vlines(x=-100, ymin=2, ymax=10,color='gray')
ax1.hlines(y=4, xmin=-150, xmax=contour_start_a1[8], color='k', linestyle='--')
ax1.hlines(y=4, xmin=contour_end_t[8], xmax=150, color='k', linestyle='--')
custom_text = r"A$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.35, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[4,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[4,:],'magenta')
ax2.hlines(y=43, xmin=-30, xmax=20,color='k')
ax2.vlines(x=20, ymin=43, ymax=58,color='k')
ax2.text(-70, 55.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-45, 41, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-75,125])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.68, 0.35, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[20,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[20,:],'magenta')
ax3.hlines(y=45, xmin=40, xmax=90,color='k')
ax3.vlines(x=90, ymin=45, ymax=60,color='k')
ax3.text(0, 57.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(20, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
# We care about the second peak only for the a-to-t connectivity, as such peaks are far less
# prominent for different values of the other connectivities
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('at', plot_frac=0.45, heterogenous=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = plt.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = plt.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
plt.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
plt.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
plt.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
plt.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
plt.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
plt.ylim([0,20])
plt.xlim([-150,150])
plt.xticks([-100,-50,0,50,100])
plt.yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$A Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 11, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 5, 100+contour_start_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.arrow(-100, 14.5, 100+contour_start_a1[29], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=11, xmin=-150, xmax=contour_start_a1[22], color='k', linestyle='--')
ax1.hlines(y=11, xmin=contour_end_t[22], xmax=150, color='k', linestyle='--')
custom_text = r"T$\rightarrow$A"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=-55, xmax=-5,color='k')
ax2.vlines(x=-5, ymin=45, ymax=60,color='k')
ax2.text(-95, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(-80, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-100,100])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[29,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[29,:],'magenta')
ax3.hlines(y=45, xmin=45, xmax=95,color='k')
ax3.vlines(x=95, ymin=45, ymax=60,color='k')
ax3.text(5, 56.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(25, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')
plt.tight_layout()
plt.show()

# %%
contour_start_a1, peaktime_a1, contour_end_a1, contour_start_a2, peaktime_a2, contour_end_a2, contour_start_t, \
            peaktime_t1, contour_end_t, shifted_a, shifted_t, zvals11, zvals12, zvals2, cmap1, cmap12, cmap2 \
            = analyze_and_prepare_plotting_1parameter('tt', plot_frac=0.45, heterogenous=True)

# %%
plt.rc('font', size=24)
plt.rc('axes', titlesize=24, labelsize=24)
plt.rc('xtick', labelsize=24)
plt.rc('ytick', labelsize=24)
fig = plt.figure(figsize=(7.1666, 5.9733))
ax1 = fig.add_subplot(1,1,1)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

img2 = ax1.imshow(zvals11, interpolation='nearest', cmap=cmap1, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
img3 = ax1.imshow(zvals2, interpolation='nearest', cmap=cmap2, origin='lower', aspect='auto', extent=[-400, 400,0, 20,])
ax1.plot(contour_start_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(peaktime_a1, xaxis_plot, linestyle='-', color='goldenrod')
ax1.plot(contour_end_a1, xaxis_plot, linestyle='--', color='goldenrod')
ax1.plot(contour_start_t, xaxis_plot, linestyle='--', color='magenta')
ax1.plot(peaktime_t1, xaxis_plot, linestyle='-', color='magenta')
ax1.plot(contour_end_t,xaxis_plot, linestyle='--', color='magenta')
ax1.set_ylim([0,20])
ax1.set_xlim([-150,150])
ax1.set_xticks([-100,-50,0,50,100])
ax1.set_yticks([0,5,10,15,20])
plt.ylabel(r'T$\rightarrow$T Connectivity [%]')
plt.xlabel('Time from A peak [ms]')
ax1.scatter(-150, 8, color='k', s=100, zorder=5,clip_on=False)
ax1.arrow(-100, 5, 100+contour_start_a1[10], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.hlines(y=8, xmin=-150, xmax=contour_start_a1[16], color='k', linestyle='--')
ax1.hlines(y=8, xmin=contour_end_t[16], xmax=150, color='k', linestyle='--')
#ax1.hlines(y=11, xmin=-100, xmax=contour_start_a1[22], color='gray', linestyle='-')
ax1.arrow(-100, 11, 100+contour_start_a1[22], 0, head_width=0.8, head_length=9, fc='gray', ec='gray',length_includes_head=True)
ax1.vlines(x=-100, ymin=11, ymax=20, color='gray', linestyle='-')
custom_text = r"T$\rightarrow$T"
ax1.text(110, 20, custom_text, backgroundcolor='none', fontsize=24, va='top', ha='left', rotation=0)

ax2 = ax1.inset_axes([0.02, 0.02, 0.3, 0.3])
ax2.spines['right'].set_visible(True)
ax2.spines['top'].set_visible(True)
ax2.spines['left'].set_visible(True)
ax2.spines['bottom'].set_visible(True)
ax2.set_xticks([])
ax2.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax2.plot(the_real_time1,shifted_a[10,:],'goldenrod')
ax2.plot(the_real_time1,shifted_t[10,:],'magenta')
ax2.hlines(y=45, xmin=65, xmax=115,color='k')
ax2.vlines(x=115, ymin=45, ymax=60,color='k')
ax2.text(20, 57, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.text(40, 43, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax2.set_xlim([-75,125])
ax2.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax2.spines['top'].set_linewidth(2)
ax2.spines['right'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)
ax2.spines['left'].set_linewidth(2)
ax2.spines['top'].set_color('gray')
ax2.spines['right'].set_color('gray') 
ax2.spines['bottom'].set_color('gray')
ax2.spines['left'].set_color('gray')

ax3 = ax1.inset_axes([0.02, 0.7, 0.3, 0.3])
ax3.spines['right'].set_visible(True)
ax3.spines['top'].set_visible(True)
ax3.spines['left'].set_visible(True)
ax3.spines['bottom'].set_visible(True)
ax3.set_xticks([])
ax3.set_yticks([])
the_real_time1=np.arange(-400,400,0.1)
ax3.plot(the_real_time1,shifted_a[22,:],'goldenrod')
ax3.plot(the_real_time1,shifted_t[22,:],'magenta')
ax3.hlines(y=50, xmin=-55, xmax=-5,color='k')
ax3.vlines(x=-5, ymin=50, ymax=65,color='k')
ax3.text(-95, 62.5, '15 sp/s', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.text(-70, 48, '50 ms', backgroundcolor='none', fontsize=14, va='top', ha='left')
ax3.set_xlim([-100,100])
ax3.tick_params(axis='both', which='both', right=False, top=False, labelright=False, labeltop=False)
ax3.spines['top'].set_linewidth(2)
ax3.spines['right'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)
ax3.spines['left'].set_linewidth(2)
ax3.spines['top'].set_color('gray')
ax3.spines['right'].set_color('gray') 
ax3.spines['bottom'].set_color('gray')
ax3.spines['left'].set_color('gray')

plt.tight_layout()
plt.show()
